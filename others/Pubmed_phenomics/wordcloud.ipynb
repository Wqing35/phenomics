# %%
library(wordcloud2)

# %%
plot_data_all <- readRDS('./plot_data_all.RDS')

# %%
wordcloud2(plot_data_all, size=0.7, color='random-dark')
# Out:
# HTML widgets cannot be represented in plain text (need html)
